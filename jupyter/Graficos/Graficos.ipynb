# %%
pip install pandas numpy matplotlib

# %%
import pandas as pd
import numpy as np
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2018', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,4,3,2,7])
plt.title('Titulo 1')
plt.ylabel('Eixo Y')
plt.xlabel('Eixo X')
plt.show()
